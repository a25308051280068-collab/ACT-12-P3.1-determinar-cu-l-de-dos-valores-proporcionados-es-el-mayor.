# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280068-collab/ACT-12-P3.1-determinar-cu-l-de-dos-valores-proporcionados-es-el-mayor./blob/main/EPPL_UII_Act_12_el_problema_3_1_DF_%2B_codigo_Python_Christian_garcia_0068.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Christian Garcia NL = 21 Fecha = 26/03/2026
# ### Calculando el cambio usando if else
# ### Mirar el diagrama de flujo
# ![Texto alternativo](https://raw.githubusercontent.com/a25308051280068-collab/ACT-12-P3.1-determinar-cu-l-de-dos-valores-proporcionados-es-el-mayor./refs/heads/main/trabajo%203.1.png)
# ## Las variables
# 1. A --> primer valor para comparar
# 2. B --> Segundo valor para comparar
# 3. M --> Resultado de la comparacion
# ## Formula
# * M = A
# * M = B
# * A > B
# ## Diagrama de flujo lucidchart
#  ![Texto alternativo](https://raw.githubusercontent.com/a25308051280068-collab/ACT-12-P3.1-determinar-cu-l-de-dos-valores-proporcionados-es-el-mayor./refs/heads/main/daigrama%20de%20flujo.PNG)

# %%
# calcula la diferencia de valor de if else
# datos de entrada A,B
# mostrar B si es falso
# mostrar A si es verdadero
A = int(input("Dame el primer valor: "))
B = int(input("Dame el segundo valor: "))
if A > B:
  M = A
else:
  M = B
print("El mayor valor es: ", M)
print("fin del programa")
print("programa realizado por Chrsitian Garcia NL = 21")
# Out:
# Dame el primer valor: 21
# Dame el segundo valor: 30
# El mayor valor es:  30
# fin del programa
# programa realizado por Chrsitian Garcia NL = 21

# %% [markdown]
# ## relacion entre codigo y diagrama de flujo
#  ![Texto alternativo](https://raw.githubusercontent.com/a25308051280068-collab/ACT-12-P3.1-determinar-cu-l-de-dos-valores-proporcionados-es-el-mayor./refs/heads/main/trabajo%20terminado.PNG)
